# %%
from toy_exp import sweep_noise_levels_and_plot

# %%
import pickle
import matplotlib.pyplot as plt

# %%
curves=pickle.load(open('/userhome/cs3/zmsxsl/ICML2026dp/figures/streaming_dp_prefix_sum_toy_exp_data.pkl', 'rb'))

# %%
plt.figure()
for z in curves.keys():
    if z<5:
        trs, mean_acc = curves[z]
        plt.plot(trs, mean_acc, label=f"$\sigma={z}$")
plt.xlabel("Round t (test rounds: 0,2,4,...)")
plt.ylabel("Running majority accuracy")
plt.title("Adversary Accuracy vs Round under Different Noise Levels")
plt.grid(True)
plt.legend()
#save the figure
plt.savefig("./figures/streaming_dp_prefix_sum_toy_exp.pdf")
plt.savefig("./figures/streaming_dp_prefix_sum_toy_exp.png")
plt.show()
